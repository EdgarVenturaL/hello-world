# %% [markdown]
# Crear un Jupyter Notebook que contenga una presentación personal y una ligera introducción a un tema cualquiera de tu licenciatura. Usar Markdown.
#
#
#
# El Notebook debe contener los siguientes puntos:
#
# Uso de título
# Uso de subtítulo
# Uso de párrafos
# Uso de negritas
# Uso de cursiva
# Una imagen
# Una lista ordenada
# Una lista con viñetas
# Una ecuación en línea $ ecuación

# %% [markdown]
# # tarea 01

# %% [markdown]
# ## simulacion matematica

# %% [markdown]
# Mi nombre es: **Edgar Omar ventura**
#
# carrera : **ING.Civil**
#
# fecha : **16/01/2023**

# %% [markdown]
# *soy Edgar Ventura, estudiante del iteso en la carrera de ING.Civil, actualmente curso mi tercer semestre.*

# %% [markdown]
# ## introdiccion al tema
#
# "La ingeniería civil es una disciplina de la ingeniería que emplea conocimientos de cálculo, mecánica, hidráulica y física para encargarse del diseño, construcción y mantenimiento de las infraestructuras emplazadas en el entorno, incluyendo carreteras, ferrocarriles, puentes, canales, presas, puertos, aeropuertos y otras construcciones relacionadas." colaboradores de Wikipedia. (2023b, enero 2). Ingeniería civil. Wikipedia, la enciclopedia libre. https://es.wikipedia.org/wiki/Ingenier%C3%ADa_civil
#
# ![image.png](attachment:image.png)
#
# ### referencias
#
# colaboradores de Wikipedia. (2023b, enero 2). Ingeniería civil. Wikipedia, la enciclopedia libre. https://es.wikipedia.org/wiki/Ingenier%C3%ADa_civil

# %% [markdown]
# lista de deportes favoritos:
#
# 1. Basquettboll
# 2. golf
# 3. Tennis
#
# Lista de pasatiempos favoritos:
# - Cantar
# - Correr
# - Leer

# %% [markdown]
# En mi semestre pasado saque las siguientes calificaciones:
#
# - 10
# - 10
# - 9
# - 9
# - 8
# - 7

# %% [markdown]
# porloque mi promedio fue de: $10+10+9+9+8+7=$
